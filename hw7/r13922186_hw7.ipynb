# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth==2025.3.19 vllm
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth==2025.3.19 vllm
# !pip install --no-deps transformers==4.50.3

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # !pip install --no-deps unsloth vllm
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # Skip restarting message in Colab
    import sys, re, requests; modules = list(sys.modules.keys())
    for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft "trl==0.15.2" triton cut_cross_entropy unsloth_zoo==2025.3.17
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer

    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt

# %% [markdown]
# ### Unsloth

# %%
from unsloth import PatchDPOTrainer

PatchDPOTrainer()
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 05-10 14:29:31 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 05-10 14:29:31 [__init__.py:239] Automatically detected platform cuda.

# %%
from unsloth import FastLanguageModel

max_seq_length = 512
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True,
)
# Out:
# ==((====))==  Unsloth 2025.3.19: Fast Llama patching. Transformers: 4.50.3. vLLM: 0.8.5.post1.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/51.1k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep

# %% [markdown]
# We first download the data files.

# %%
# !git clone https://gitlab.com/lchengtw/ML2025Spring-HW7.git
# Out:
# Cloning into 'ML2025Spring-HW7'...
# remote: Enumerating objects: 9, done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 9 (from 1)
# Receiving objects: 100% (9/9), 8.63 KiB | 4.32 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# Then, we load the json file here.

# %%
import json

with open("/content/ML2025Spring-HW7/train.json", 'r') as jsonfile:
    full_data = json.load(jsonfile)

with open("/content/ML2025Spring-HW7/test.json", 'r') as jsonfile:
    test_data = json.load(jsonfile)

# %% [markdown]
# We define how we prepare the messages for the model and how we extract the response from the model

# %%
import re

def data_formulate(data):
    messages = [
        {"role": "system", "content": "Your entire response must be 100 characters or less."},
        {"role": "user", "content": data['prompt']},
    ]
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return prompt

def extract_assistant_response(text):
    try:
        # Split by assistant header marker
        parts = text.split("<|start_header_id|>assistant<|end_header_id|>")
        if len(parts) < 2:
            return None

        # Split by end of text marker
        assistant_part = parts[1]
        response_parts = assistant_part.split("<|eot_id|>")

        # Clean up any whitespace
        return response_parts[0].strip()
    except Exception as e:
        print(f"Error extracting assistant response: {e}")
        return None

# %% [markdown]
# Let's observe how the model responses before aligning it.

# %%
# original_model_response = []
# for data in test_data:
#     id = data['id']
#     prompt = data['prompt']
#     print(f'\nQuestion {id}: {prompt}')
#     inputs = data_formulate(data)
#     outputs = model.generate(
#         **tokenizer(inputs, return_tensors = "pt").to("cuda"),
#         max_new_tokens = 128,
#         do_sample=False
#     )
#     output = tokenizer.batch_decode(outputs)[0]
#     output = extract_assistant_response(output)
#     original_model_response.append(output)
#     print()
#     print(output)

# %% [markdown]
# Now we preapre the data for aligning.
#
# Please adjust the parameters here to complete the observations for the assignment.

# %%
# TODO: Adjust the parameters here
num_epoch = 3
data_size = 50
support_ratio = 0

# %%
#### DO NOT CHANGE ####

from datasets import Dataset

# Select part of the data for training
training_data = full_data[:data_size]

# Define the size of the support dataset
support_data_size = int(data_size * support_ratio)

# Prepare the data for the training dataset
prompt_list = [data_formulate(data) for data in training_data]
chosen_list = [data['support'] for data in training_data[:support_data_size]] + [data['oppose'] for data in training_data[support_data_size:]]
rejected_list = [data['oppose'] for data in training_data[:support_data_size]] + [data['support'] for data in training_data[support_data_size:]]

# Create the training dataset
train_dataset = Dataset.from_dict({'prompt': prompt_list, 'chosen': chosen_list, 'rejected': rejected_list})

# %% [markdown]
# Now let's take a look on an example of the prompt, the chosen response and the rejected response.

# %%
prompt_list[0]
# Out:
# "<|begin_of_text|><|start_header_id|>system<|end_header_id|>\n\nYour entire response must be 100 characters or less.<|eot_id|><|start_header_id|>user<|end_header_id|>\n\nDoes AI-generated Ghibli-style art preserve the artistic integrity of the original studio's work?<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n\n"

# %%
chosen_list[0]
# Out:
# 'AI-generated art lacks the human intentionality and cultural context that gives Ghibli works their soul and meaning, undermining their artistic integrity.'

# %%
rejected_list[0]
# Out:
# "AI-generated Ghibli-style art can faithfully capture the distinctive visual elements that make the studio's style recognizable, preserving its aesthetic integrity."

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters.
#
# Please do not change anything here.

# %%
#### DO NOT CHANGE ####

model = FastLanguageModel.get_peft_model(
    model,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],

    r = 16,           # Larger = higher accuracy, but might overfit
    lora_alpha = 16,  # Recommended alpha == r at least
    lora_dropout = 0.1,
    bias = "none",
    random_state = 3407, # Do not modify the random_state for reproducibility
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.1.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2025.3.19 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %% [markdown]
# <a name="Train"></a>
# ### Train the DPO model

# %% [markdown]
# Now we define the trainer.
#
# Please (also) do not change anything here.

# %%
#### DO NOT CHANGE ####

from transformers import TrainingArguments
from trl import DPOTrainer, DPOConfig
from unsloth import is_bfloat16_supported

dpo_trainer = DPOTrainer(
    model = model,
    ref_model = None,
    args = DPOConfig(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_ratio = 0.1,
        num_train_epochs = num_epoch,
        learning_rate = 1e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "paged_adamw_8bit",
        weight_decay = 0.0,
        lr_scheduler_type = "linear",
        seed = 42,
        output_dir = "outputs",
        report_to = "none",
    ),
    beta = 0.1,
    train_dataset = train_dataset,
    tokenizer = tokenizer,
)
# Out:
# Extracting prompt in train dataset (num_proc=2):   0%|          | 0/50 [00:00<?, ? examples/s]
# Applying chat template to train dataset (num_proc=2):   0%|          | 0/50 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=2):   0%|          | 0/50 [00:00<?, ? examples/s]

# %% [markdown]
# Now we start training!

# %%
dpo_trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 50 | Num Epochs = 3 | Total steps = 18
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040/8,000,000,000 (0.52% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='18' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18/18 02:03, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>rewards / chosen</th>
#       <th>rewards / rejected</th>
#       <th>rewards / accuracies</th>
#       <th>rewards / margins</th>
#       <th>logps / chosen</th>
#       <th>logps / rejected</th>
#       <th>logits / chosen</th>
#       <th>logits / rejected</th>
#       <th>eval_logits / chosen</th>
#       <th>eval_logits / rejected</th>
#       <th>nll_loss</th>
#       <th>aux_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.693100</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-73.929001</td>
#       <td>-69.665436</td>
#       <td>-0.745684</td>
#       <td>-0.795255</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.693100</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-74.884827</td>
#       <td>-66.882927</td>
#       <td>-0.903795</td>
#       <td>-0.872076</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.662000</td>
#       <td>0.040865</td>
#       <td>-0.022801</td>
#       <td>1.000000</td>
#       <td>0.063666</td>
#       <td>-77.722000</td>
#       <td>-66.221581</td>
#       <td>-0.761269</td>
#       <td>-0.680487</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.564300</td>
#       <td>0.120754</td>
#       <td>-0.168231</td>
#       <td>0.875000</td>
#       <td>0.288985</td>
#       <td>-68.179741</td>
#       <td>-73.211922</td>
#       <td>-0.775138</td>
#       <td>-0.721091</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.464700</td>
#       <td>0.158503</td>
#       <td>-0.386587</td>
#       <td>1.000000</td>
#       <td>0.545090</td>
#       <td>-83.455505</td>
#       <td>-72.119553</td>
#       <td>-0.845839</td>
#       <td>-0.747705</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.429100</td>
#       <td>0.322234</td>
#       <td>-0.344143</td>
#       <td>1.000000</td>
#       <td>0.666377</td>
#       <td>-72.691437</td>
#       <td>-67.913765</td>
#       <td>-0.876513</td>
#       <td>-0.791008</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.043600</td>
#       <td>0.579847</td>
#       <td>-1.112825</td>
#       <td>1.000000</td>
#       <td>1.692673</td>
#       <td>-70.257004</td>
#       <td>-74.272774</td>
#       <td>-0.737327</td>
#       <td>-0.921603</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.069100</td>
#       <td>1.147518</td>
#       <td>-1.755650</td>
#       <td>1.000000</td>
#       <td>2.903168</td>
#       <td>-60.210899</td>
#       <td>-78.695663</td>
#       <td>-0.807187</td>
#       <td>-0.829188</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.110500</td>
#       <td>1.366013</td>
#       <td>-1.067130</td>
#       <td>1.000000</td>
#       <td>2.433144</td>
#       <td>-59.870365</td>
#       <td>-84.527069</td>
#       <td>-0.783434</td>
#       <td>-0.716401</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.058200</td>
#       <td>1.462821</td>
#       <td>-1.848702</td>
#       <td>1.000000</td>
#       <td>3.311523</td>
#       <td>-68.298431</td>
#       <td>-85.127762</td>
#       <td>-0.819775</td>
#       <td>-0.837118</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.086500</td>
#       <td>1.238158</td>
#       <td>-1.601882</td>
#       <td>1.000000</td>
#       <td>2.840040</td>
#       <td>-63.832531</td>
#       <td>-88.346031</td>
#       <td>-0.835216</td>
#       <td>-0.904680</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.055800</td>
#       <td>1.688377</td>
#       <td>-1.773942</td>
#       <td>1.000000</td>
#       <td>3.462319</td>
#       <td>-56.306660</td>
#       <td>-82.215576</td>
#       <td>-0.878537</td>
#       <td>-0.799498</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.042700</td>
#       <td>1.408314</td>
#       <td>-2.706935</td>
#       <td>1.000000</td>
#       <td>4.115249</td>
#       <td>-63.407619</td>
#       <td>-94.646851</td>
#       <td>-0.939412</td>
#       <td>-0.927268</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.001600</td>
#       <td>2.423503</td>
#       <td>-2.789223</td>
#       <td>1.000000</td>
#       <td>5.212726</td>
#       <td>-60.759060</td>
#       <td>-94.136734</td>
#       <td>-0.913633</td>
#       <td>-0.662723</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.029000</td>
#       <td>1.677617</td>
#       <td>-2.950100</td>
#       <td>1.000000</td>
#       <td>4.627717</td>
#       <td>-53.001503</td>
#       <td>-88.322533</td>
#       <td>-0.847154</td>
#       <td>-0.778497</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.018700</td>
#       <td>1.781062</td>
#       <td>-2.795762</td>
#       <td>1.000000</td>
#       <td>4.576824</td>
#       <td>-48.474350</td>
#       <td>-102.536690</td>
#       <td>-0.892245</td>
#       <td>-0.827411</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.014800</td>
#       <td>1.276521</td>
#       <td>-3.391400</td>
#       <td>1.000000</td>
#       <td>4.667920</td>
#       <td>-59.478615</td>
#       <td>-101.751816</td>
#       <td>-0.796969</td>
#       <td>-0.937706</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.007500</td>
#       <td>1.406776</td>
#       <td>-4.230472</td>
#       <td>1.000000</td>
#       <td>5.637248</td>
#       <td>-65.525452</td>
#       <td>-111.824203</td>
#       <td>-0.923288</td>
#       <td>-0.826166</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=18, training_loss=0.22468118908970305, metrics={'train_runtime': 143.4706, 'train_samples_per_second': 1.046, 'train_steps_per_second': 0.125, 'total_flos': 0.0, 'train_loss': 0.22468118908970305, 'epoch': 2.64})

# %% [markdown]
# After training, we utilize the model to do the inference on the test again to see how it differs from the original model.

# %%
# aligned_model_response = []
# for data in test_data:
#     id = data['id']
#     prompt = data['prompt']
#     print(f'\nQuestion {id}: {prompt}')
#     inputs = data_formulate(data)
#     outputs = model.generate(
#         **tokenizer(inputs, return_tensors = "pt").to("cuda"),
#         max_new_tokens = 128,
#         do_sample=False
#     )
#     output = tokenizer.batch_decode(outputs)[0]
#     output = extract_assistant_response(output)
#     aligned_model_response.append(output)
#     print()
#     print(output)

# %% [markdown]
# Next, we save the results in .json for your NTU COOL submission.
#
# Please note that this is designed for Colab, you may have to change the directory name for other machines.

# %%
# student_id = "r13922186" # TODO: fill in your student id here.
# dir_name = "/content" # TODO: If you use machines other than colab, please adjust the directory here.
# # Do NOT change the following for this block.
# file_name = f"{dir_name}/{student_id}_hw7_epoch{num_epoch}_ratio{support_ratio}_size{data_size}.json"
# output_list = []
# for data in test_data:
#   original_response = original_model_response.pop(0)
#   aligned_response = aligned_model_response.pop(0)
#   output_list.append({"id": data["id"], "prompt": data["prompt"], "original_response": original_response, "aligned_response": aligned_response})
# output_data = {"num_epoch": num_epoch, "data_size": data_size, "support_ratio": support_ratio, "results": output_list}
# with open(file_name, "w") as output_file:
#     json.dump(output_data, output_file, indent=4)

# %% [markdown]
# Finally, we provide code for free testing.
#
#
#
# You may freely adjust the system prompt, user prompt and generate settings here for model behavior observations.

# %% [markdown]
# #### Q2.1

# %%
def make_prompt(system, prompt):
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": prompt},
    ]
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return prompt

# TODO: Try your system prompt and user prompt here.
system = "Your entire response must be longer than 120 characters."
prompt = "Does AI-generated Ghibli-style art cheapen the meticulous hand-drawn animation process central to the studio's identity?"

inputs = make_prompt(system, prompt)
outputs = model.generate(
    **tokenizer(inputs, return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # TODO: You may use this for early stop.
    do_sample=False, # Please keep this to False and do not tweak other parameters.
)
output = tokenizer.batch_decode(outputs)[0]
output = extract_assistant_response(output)
print(output)
# Out:
# The question of whether AI-generated Ghibli-style art cheapens the meticulous hand-drawn animation process central to the studio's identity is a complex one, and opinions on the matter are likely to be divided.
#
# On one hand, Ghibli's founder Hayao Miyazaki and other studio members have been vocal about their commitment to traditional hand-drawn animation, which they believe is essential to the studio's unique aesthetic and storytelling approach. The painstaking attention to detail, the subtle nuances of line and color, and the emotional resonance of hand-drawn animation are all integral to the Ghibli experience. The studio's films are often praised for their beautiful, intricate backgrounds, memorable characters, and captivating storylines, all of which are made possible by the labor-intensive process of hand-drawing every frame.
#
# On the other hand, AI-generated art has the potential to mimic the style and aesthetic of Ghibli's work, albeit with a significantly reduced level of effort and cost. AI algorithms can analyze and replicate the visual patterns and techniques used in Ghibli's films, creating a superficially similar look without the need for human intervention. This raises questions about the value and authenticity of such work, particularly when compared to the painstaking process of hand-drawn animation.
#
# Moreover, the use of AI-generated art in Ghibli-style animation could potentially undermine the studio's commitment to traditional animation techniques and the skills required to master them. The studio's animators and artists have spent years honing their craft, and the process of hand-drawing every frame is an integral part of their creative process. If AI-generated art becomes the norm, it could lead to a devaluation of the skills and expertise that Ghibli's artists have developed over the years.
#
# Furthermore, the use of AI-generated art could also lead to a homogenization of styles and a loss of diversity in animation. Ghibli's films are known for their unique blend of traditional Japanese culture, folklore, and mythology, as well as their exploration of complex themes and emotions. AI-generated art, on the other hand, is more likely to produce generic, formulaic, and uninspired work that lacks the depth and nuance of human-created animation.
#
# In conclusion, while AI-generated Ghibli-style art may be able to mimic the studio's aesthetic, it cannot replicate the soul and essence of their work. The meticulous hand-drawn animation process is an integral part of Ghibli's identity, and the use of AI-generated art would likely cheapen the studio's reputation and undermine the

# %% [markdown]
# #### Q2.2

# %%
def make_prompt(system, prompt):
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": prompt},
    ]
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return prompt

# TODO: Try your system prompt and user prompt here.
system = "Your entire response must be 100 characters or less."
prompts = ["Is it ethical for AI to generate One Piece-style art?", "Is it ethical for AI to generate Disney-style art?"]

for prompt in prompts:
    inputs = make_prompt(system, prompt)
    outputs = model.generate(
        **tokenizer(inputs, return_tensors = "pt").to("cuda"),
        max_new_tokens = 512, # TODO: You may use this for early stop.
        do_sample=False, # Please keep this to False and do not tweak other parameters.
    )
    output = tokenizer.batch_decode(outputs)[0]
    output = extract_assistant_response(output)
    print(output, "\n")
# Out:
# Without explicit permission from the original creators, it's a copyright infringement.
#
# Without human creativity and intention, AI-generated Disney-style art lacks the soul and cultural significance that Disney's original creators poured into their work.

# %% [markdown]
# #### Q2.3

# %%
def make_prompt(system, prompt):
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": prompt},
    ]
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return prompt

# TODO: Try your system prompt and user prompt here.
system = "Your entire response must be 100 characters or less."
prompt = "Is it ethical for AI to generate Bach-style music?"

inputs = make_prompt(system, prompt)
outputs = model.generate(
    **tokenizer(inputs, return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # TODO: You may use this for early stop.
    do_sample=False, # Please keep this to False and do not tweak other parameters.
)
output = tokenizer.batch_decode(outputs)[0]
output = extract_assistant_response(output)
print(output)
# Out:
# No, it's not ethical. Bach's music is a product of his human experience, emotions, and cultural context, which cannot be replicated by AI.

# %% [markdown]
# #### Q2.4

# %%
def make_prompt(system, prompt):
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": prompt},
    ]
    prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return prompt

# TODO: Try your system prompt and user prompt here.
system = "請使用中文回答。"
prompt = "讓 AI 生成吉卜力風格的藝術作品是道德的嗎？"

inputs = make_prompt(system, prompt)
outputs = model.generate(
    **tokenizer(inputs, return_tensors = "pt").to("cuda"),
    max_new_tokens = 512, # TODO: You may use this for early stop.
    do_sample=False, # Please keep this to False and do not tweak other parameters.
)
output = tokenizer.batch_decode(outputs)[0]
output = extract_assistant_response(output)
print(output)
# Out:
# 生成吉卜力風格的藝術作品是否道德是個複雜的問題。吉卜力風格的藝術作品通常是指日本動畫師宮崎駿（Hayao Miyazaki）和Studio Ghibli所創作的作品，具有濃郁的日本文化和自然環境的描繪，具有濃郁的藝術價值和哲學意義。
#
# 然而，使用AI生成吉卜力風格的藝術作品是否道德，需要考慮以下幾個問題：
#
# 1. 吉卜力風格的藝術作品是人類創造的，具有藝術家對作品的創作意義和情感投入。AI生成的作品是否能夠捕捉到這種創作意義和情感？
# 2. 吉卜力風格的藝術作品是根據人類的觀察和體驗所創造的，具有對自然和文化的理解和尊重。AI生成的作品是否能夠捕捉到這種對自然和文化的理解和尊重？
# 3. 吉卜力風格的藝術作品是人類的創造，具有藝術家的個性和風格。AI生成的作品是否能夠捕捉到這種個性和風格？
#
# 總之，生成吉卜力風格的藝術作品是否道德，需要考慮到藝術家的創作意義、對自然和文化的理解和尊重，以及藝術家的個性和風格。

# %% [markdown]
# And that's it for homework 7! If you have any questions, please consider posting questions in the discussion forum first so all the classmates can benefit. TAs will also prioritize responding to questions posted there.
#
# Also, please make sure that you have completed the submission for both GradeScope and NTU Cool.
#
# Good luck!
